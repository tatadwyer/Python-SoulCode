# %%
'''
1-Deve-se criar 5 funções diferentes, sendo elas somar, subtrair, dividir, multiplicar e listar.
2-Deve-se criar um MENU com if else sendo que o usuário escolha qual função deve acessar.
3-Ao ser escolhida a função, o usuário é direcionado a ela e insere os parâmetros que desejam 
realizar as operações.
4-As funções matemáticas devem receber os números para realizar a operação, 
realizar o cálculo e imprimir o resultado para o usuário.
5-Na função listar, deve-se criar uma lista de vantagens do python e imprimir para o usuário.
'''

menu = '''
************MENU************

Somatória:          a+b (add)
Subtração:          a-b (sub)
Multiplicação:      a*b (mult)
Divisão:            a/b (div)

Listar:             Saiba os beneficios de utilizar o Pyhton. (listar)

'''

listar = '''

Benefícios de usar o Python:

- Fácil aprendizado.
- Simples de programar.
- Sintaxe intuitiva.
- Open Source.
- Multiplataforma.
- Grande quantidade de bibliotecas disponíveis.
- Grande comunidade de usuários.
- Documentação extensa.
- Número de oportunidades no mercado de trabalho.

'''

options = ['listar', 'add', 'sub', 'mult', 'div']
a=0
b=0
choice=''

def add(a=0,b=0):
    add = a+b
    return add

def sub(a=0,b=0):
    sub = a-b
    return sub

def mult(a=0,b=0):
    mult = a*b
    return mult

def div(a=0,b=0):
    div = a/b
    return div

print(menu)

choice = input("Escolha uma função: ").lower()
while choice not in options:
    choice = input("Opção inválida. Tente denovo.")
    
if choice == 'listar':
    print(listar)

else:
    a = float(input('Digite o primeiro número: '))
    b = float(input('Digite o segundo número: '))
    
if choice == 'add':
    print("Adição: ", a, " + ", b, " = ", (add(a,b)))
    
elif choice == 'sub':
    print("Subtração: ", a, " - ", b, " = ", (sub(a,b)))

elif choice == 'mult':
    print("Multiplicação: ", a, " * ", b, " = ", (mult(a,b)))
    
elif choice == 'div':
    print("Divisão: ", a, " / ", b, " = ", (div(a,b)))

# %%
'''
1-Deve-se criar 5 funções diferentes, sendo elas somar, subtrair, dividir, multiplicar e listar.
2-Deve-se criar um MENU com if else sendo que o usuário escolha qual função deve acessar.
3-Ao ser escolhida a função, o usuário é direcionado a ela e insere os parâmetros que desejam 
realizar as operações.
4-As funções matemáticas devem receber os números para realizar a operação, 
realizar o cálculo e imprimir o resultado para o usuário.
5-Na função listar, deve-se criar uma lista de vantagens do python e imprimir para o usuário.
'''

#Opção de exercício, parar treino.

menu = '''
************MENU************

Somatória:          a+b (add)
Subtração:          a-b (sub)
Multiplicação:      a*b (mult)
Divisão:            a/b (div)

Listar:             Saiba os beneficios de utilizar o Pyhton. (listar)

'''

listar = '''

Benefícios de usar o Python:

- Fácil aprendizado.
- Simples de programar.
- Sintaxe intuitiva.
- Open Source.
- Multiplataforma.
- Grande quantidade de bibliotecas disponíveis.
- Grande comunidade de usuários.
- Documentação extensa.
- Número de oportunidades no mercado de trabalho.

'''

options = ['listar', 'add', 'sub', 'mult', 'div']
a=0
b=0
choice=''
result = 0

print(menu)

choice = input("Escolha uma função: ").lower()
while choice not in options:
    choice = input("Opção inválida. Tente denovo.")
    
if choice == 'listar':
    print(listar)

else:
    a = float(input('Digite o primeiro número: '))
    b = float(input('Digite o segundo número: '))
    
if choice == 'add':
    choice = a + b
    print("Adição: ", a, " + ", b, " = ", choice)
    
elif choice == 'sub':
    choice = a - b
    print("Subtração: ", a, " - ", b, " = ", choice)

elif choice == 'mult':
    choice = a * b
    print("Multiplicação: ", a, " * ", b, " = ", choice)
    
elif choice == 'div':
    choice = a / b
    print("Divisão: ", a, " / ", b, " = ", choice)
